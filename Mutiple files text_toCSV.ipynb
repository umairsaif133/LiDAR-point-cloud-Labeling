# %%
import pandas as pd, glob, re, os

# --- Path containing your .txt files ---
folder_path = r"C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1"

# --- Create output folder ---
output_folder = os.path.join(folder_path, "Potholes_clean_csvs")
os.makedirs(output_folder, exist_ok=True)

# --- Get list of all .txt files ---
txt_files = glob.glob(os.path.join(folder_path, "*.txt"))
print(f"Found {len(txt_files)} .txt files in {folder_path}")

for txt_file in txt_files:
    try:
        # --- Read file ---
        df = pd.read_csv(txt_file, skiprows=1, sep=',', engine='python')
        df = df[["Name", "X", "Y", "Z"]]

        # --- Extract type (P, C, E) and number ---
        def extract_type_and_number(name):
            m = re.search(r'([PCE])(\d+)', name)
            return (m.group(1), int(m.group(2))) if m else (None, -1)
        df[['Type', 'Number']] = df['Name'].apply(lambda x: pd.Series(extract_type_and_number(x)))

        # --- Extract base name (without _S / _F) for proper grouping ---
        df['Base'] = df['Name'].apply(lambda x: re.sub(r'_[SF]$', '', x))

        # --- Define sort keys ---
        df['SF'] = df['Name'].apply(lambda x: 0 if x.endswith('_S') else 1)  # S before F
        order_map = {'P': 1, 'C': 2, 'E': 3}
        df['TypeOrder'] = df['Type'].map(order_map).fillna(99)

        # --- Sort by site type, number, then ensure S comes before F ---
        df = df.sort_values(by=['TypeOrder', 'Number', 'Base', 'SF']).drop(columns=['TypeOrder', 'SF', 'Type', 'Number', 'Base'])

        # --- Define output file path ---
        base_name = os.path.basename(txt_file).replace(".txt", "_clean.csv")
        csv_file = os.path.join(output_folder, base_name)

        # --- Save cleaned CSV ---
        df.to_csv(csv_file, index=False, float_format="%.3f")
        print(f"✅ Saved cleaned CSV → {csv_file}")

    except Exception as e:
        print(f"❌ Error processing {txt_file}: {e}")

print(f"\n🎯 All cleaned CSVs saved in: {output_folder}")
# Out:
# Found 15 .txt files in C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_0_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_1_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_10_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_11_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_12_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_13_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_14_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_2_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_3_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_4_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_5_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_6_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_7_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_8_P_1_S_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_9_clean.csv
#
# 🎯 All cleaned CSVs saved in: C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs

# %%
import pandas as pd, glob, re, os

# --- Path containing your .txt files ---
folder_path = r"C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1"  # change as needed

# --- Create output folder inside the same directory ---
output_folder = os.path.join(folder_path, "clean_csvs")
os.makedirs(output_folder, exist_ok=True)

# --- Get list of all .txt files ---
txt_files = glob.glob(os.path.join(folder_path, "*.txt"))
print(f"Found {len(txt_files)} .txt files in {folder_path}")

for txt_file in txt_files:
    try:
        # --- Read file ---
        df = pd.read_csv(txt_file, skiprows=1, sep=',', engine='python')
        df = df[["Name", "X", "Y", "Z"]]

        # --- Extract type (P, C, E) and number ---
        def extract_type_and_number(name):
            m = re.search(r'([PCE])_(\d+)', str(name))
            return (m.group(1), int(m.group(2))) if m else (None, -1)

        df[['Type', 'Number']] = df['Name'].apply(lambda x: pd.Series(extract_type_and_number(x)))

        # --- Identify S/F flag ---
        def sf_flag(name):
            if '_S' in name:
                return 0  # S first
            elif '_F' in name:
                return 1  # F second
            else:
                return 2  # others (if any)
        df['SF'] = df['Name'].apply(sf_flag)

        # --- Create a "Base" key to ensure S and F stay together ---
        # Example: Site1_0_P1_S → Site1_0_P1
        df['Base'] = df['Name'].apply(lambda x: re.sub(r'(_[SF])$', '', str(x)))

        # --- Define type ordering ---
        order_map = {'P': 1, 'C': 2, 'E': 3}
        df['TypeOrder'] = df['Type'].map(order_map).fillna(99)

        # --- Sort so that:
        #     1. Type: P → C → E
        #     2. Number ascending
        #     3. Within each pair, S before F
        df = df.sort_values(by=['TypeOrder', 'Number', 'Base', 'SF']).drop(columns=['TypeOrder', 'SF', 'Type', 'Number', 'Base'])

        # --- Define output file path inside new folder ---
        base_name = os.path.basename(txt_file).replace(".txt", "_clean.csv")
        csv_file = os.path.join(output_folder, base_name)

        # --- Save cleaned CSV ---
        df.to_csv(csv_file, index=False, float_format="%.3f")
        print(f"✅ Saved cleaned CSV → {csv_file}")

    except Exception as e:
        print(f"❌ Error processing {txt_file}: {e}")

print(f"\n🎯 All cleaned CSVs saved in: {output_folder}")
# Out:
# Found 15 .txt files in C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_0_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_1_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_10_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_11_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_12_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_13_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_14_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_2_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_3_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_4_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_5_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_6_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_7_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_8_P_1_S_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_9_clean.csv
#
# 🎯 All cleaned CSVs saved in: C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs

# %%
import os
import re
import pandas as pd

# ----------------------------
# 1. FIXED & SAFE REGEX PATTERNS
# ----------------------------
PATTERNS = [

    # Pattern A — Site1_1_P4_S
    re.compile(
        r'^(?P<site>Site\d+)(?:[_-](?P<sub>\d+))?[_-]'
        r'(?P<type>P|C|E|Fl|FL|fl|Flushed|FLUSHED)'
        r'(?P<num>\d+)[_-](?P<sf>[SF])$',
        re.IGNORECASE
    ),

    # Pattern B — Site1_4_P_5_F
    re.compile(
        r'^(?P<site>Site\d+)(?:[_-](?P<sub>\d+))?[_-]'
        r'(?P<type>P|C|E|Fl|FL|fl|Flushed|FLUSHED)[_-]'
        r'(?P<num>\d+)[_-](?P<sf>[SF])$',
        re.IGNORECASE
    ),

    # Pattern C — Site2_1_P_S_11
    re.compile(
        r'^(?P<site>Site\d+)(?:[_-](?P<sub>\d+))?[_-]'
        r'(?P<type>P|C|E|Fl|FL|fl|Flushed|FLUSHED)[_-]'
        r'(?P<sf>[SF])[_-](?P<num>\d+)$',
        re.IGNORECASE
    ),

    # Pattern D — fallback: Site1_1_P4F
    re.compile(
        r'^(?P<site>Site\d+)(?:[_-](?P<sub>\d+))?[_-]'
        r'(?P<type>P|C|E|Fl|FL|fl|Flushed|FLUSHED)'
        r'(?P<num>\d+)(?P<sf>[SF])$',
        re.IGNORECASE
    ),
]


# -------------------------------------
# 2. FUNCTION TO PARSE A SINGLE FILENAME
# -------------------------------------
def parse_line(line):
    line = line.strip()

    for pat in PATTERNS:
        match = pat.match(line)
        if match:
            site = match.group("site")
            sub = match.group("sub")
            tp = match.group("type")
            num = match.group("num")
            sf = match.group("sf")

            # Strong filtering: S or F must be present
            if tp is None or num is None or sf is None:
                return None

            return {
                "site": site,
                "sub": sub if sub else "",
                "type": tp.upper(),
                "num": int(num),
                "SF": sf.upper(),
                "raw": line
            }

    return None  # Not matching any pattern → discard


# -------------------------------------------
# 3. PROCESS ONE TXT FILE → CREATE ONE CSV OUT
# -------------------------------------------
def process_txt_file(txt_path, out_dir):
    filename = os.path.basename(txt_path)

    with open(txt_path, "r") as f:
        lines = f.readlines()

    parsed = [parse_line(L) for L in lines]
    parsed = [p for p in parsed if p is not None]  # remove failures

    if not parsed:
        print(f"[WARNING] All lines rejected in {filename}")
        return

    df = pd.DataFrame(parsed)

    # --- FORM PAIRS (S + F) -----------------
    df["pair_id"] = df["site"] + "_" + df["sub"].astype(str) + "_" + df["type"] + "_" + df["num"].astype(str)

    # Keep only pair_ids where both S and F exist
    valid_pairs = df.groupby("pair_id")["SF"].nunique()
    keep_ids = valid_pairs[valid_pairs == 2].index

    df_clean = df[df["pair_id"].isin(keep_ids)].copy()

    # Save CSV same name as txt
    out_csv = os.path.join(out_dir, filename.replace(".txt", ".csv"))
    df_clean.to_csv(out_csv, index=False)

    print(f"[OK] Saved: {out_csv}   Rows: {len(df_clean)}")


# ----------------------------
# 4. MAIN EXECUTION
# ----------------------------
input_folder = "C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables"            # your TXT folder
output_folder = "C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs"      # output folder

os.makedirs(output_folder, exist_ok=True)

for file in os.listdir(input_folder):
    if file.lower().endswith(".txt"):
        process_txt_file(os.path.join(input_folder, file), output_folder)

print("\nDONE! All CSVs saved inside /cleancsvs/")
# Out:
# [WARNING] All lines rejected in Site1_0.txt
# [WARNING] All lines rejected in Site1_1.txt
# [WARNING] All lines rejected in Site1_10.txt
# [WARNING] All lines rejected in Site1_11.txt
# [WARNING] All lines rejected in Site1_12.txt
# [WARNING] All lines rejected in Site1_13.txt
# [WARNING] All lines rejected in Site1_14.txt
# [WARNING] All lines rejected in Site1_2.txt
# [WARNING] All lines rejected in Site1_3.txt
# [WARNING] All lines rejected in Site1_4.txt
# [WARNING] All lines rejected in Site1_5.txt
# [WARNING] All lines rejected in Site1_6.txt
# [WARNING] All lines rejected in Site1_7.txt
# [WARNING] All lines rejected in Site1_8.txt
# [WARNING] All lines rejected in Site1_9.txt
# [WARNING] All lines rejected in Site2_0.txt
# [WARNING] All lines rejected in Site2_1.txt
# [WARNING] All lines rejected in Site2_10.txt
# [WARNING] All lines rejected in Site2_11.txt
# [WARNING] All lines rejected in Site2_2.txt
# [WARNING] All lines rejected in Site2_3.txt
# [WARNING] All lines rejected in Site2_4.txt
# [WARNING] All lines rejected in Site2_5.txt
# [WARNING] All lines rejected in Site2_7.txt
# [WARNING] All lines rejected in Site2_9.txt
# [WARNING] All lines rejected in Site3_0.txt
# [WARNING] All lines rejected in Site3_1.txt
# [WARNING] All lines rejected in Site3_2.txt
# [WARNING] All lines rejected in Site3_3.txt
# [WARNING] All lines rejected in Site3_4.txt
# [WARNING] All lines rejected in Site4_0.txt
# [WARNING] All lines rejected in Site4_1.txt
# [WARNING] All lines rejected in Site4_10.txt
# [WARNING] All lines rejected in Site4_11.txt
# [WARNING] All lines rejected in Site4_2.txt
# [WARNING] All lines rejected in Site4_3.txt
# [WARNING] All lines rejected in Site4_4.txt
# [WARNING] All lines rejected in Site4_5.txt
# [WARNING] All lines rejected in Site4_6.txt
# [WARNING] All lines rejected in Site4_7.txt
# [WARNING] All lines rejected in Site4_8.txt
# [WARNING] All lines rejected in Site5_0.txt
# [WARNING] All lines rejected in Site5_1.txt
# [WARNING] All lines rejected in Site5_10.txt
# [WARNING] All lines rejected in Site5_11.txt
# [WARNING] All lines rejected in Site5_12.txt
# [WARNING] All lines rejected in Site5_13.txt
# [WARNING] All lines rejected in Site5_14.txt
# [WARNING] All lines rejected in Site5_16.txt
# [WARNING] All lines rejected in Site5_17.txt
# [WARNING] All lines rejected in Site5_18.txt
# [WARNING] All lines rejected in Site5_19.txt
# [WARNING] All lines rejected in Site5_2.txt
# [WARNING] All lines rejected in Site5_3.txt
# [WARNING] All lines rejected in Site5_4.txt
# [WARNING] All lines rejected in Site5_5.txt
# [WARNING] All lines rejected in Site5_6.txt
# [WARNING] All lines rejected in Site5_7.txt
# [WARNING] All lines rejected in Site5_8.txt
# [WARNING] All lines rejected in Site6_0.txt
# [WARNING] All lines rejected in Site6_1.txt
# [WARNING] All lines rejected in Site6_11.txt
# [WARNING] All lines rejected in Site6_3.txt
# [WARNING] All lines rejected in Site6_5.txt
# [WARNING] All lines rejected in Site6_7.txt
# [WARNING] All lines rejected in Site7_0.txt
# [WARNING] All lines rejected in Site7_1.txt
# [WARNING] All lines rejected in Site7_2.txt
# [WARNING] All lines rejected in Site8P2_0.txt
# [WARNING] All lines rejected in Site8P2_1.txt
# [WARNING] All lines rejected in Site8P2_10.txt
# [WARNING] All lines rejected in Site8P2_11.txt
# [WARNING] All lines rejected in Site8p2_2.txt
# [WARNING] All lines rejected in Site8P2_3.txt
# [WARNING] All lines rejected in Site8P2_4.txt
# [WARNING] All lines rejected in Site8P2_5.txt
# [WARNING] All lines rejected in Site8P2_6.txt
# [WARNING] All lines rejected in Site8P2_7.txt
# [WARNING] All lines rejected in Site8P2_8.txt
# [WARNING] All lines rejected in Site8P2_9.txt
# [WARNING] All lines rejected in Site8_0.txt
# [WARNING] All lines rejected in Site8_1.txt
# [WARNING] All lines rejected in Site8_2.txt
# [WARNING] All lines rejected in Site8_4.txt
# [WARNING] All lines rejected in Site8_5.txt
# [WARNING] All lines rejected in Site8_6.txt
# [WARNING] All lines rejected in Site8_7.txt
# [WARNING] All lines rejected in SiteV1_1.txt
# [WARNING] All lines rejected in SiteV1_2.txt
# [WARNING] All lines rejected in SiteV1_3.txt
# [WARNING] All lines rejected in SiteV1_4.txt
# [WARNING] All lines rejected in SiteV1_5.txt
# [WARNING] All lines rejected in SiteV1_6.txt
# [WARNING] All lines rejected in SiteV2_0.txt
# [WARNING] All lines rejected in SiteV2_1.txt
# [WARNING] All lines rejected in SiteV2_11.txt
# [WARNING] All lines rejected in SiteV2_12.txt
# [WARNING] All lines rejected in SiteV2_14.txt
# [WARNING] All lines rejected in SiteV2_15.txt
# [WARNING] All lines rejected in SiteV2_16.txt
# [WARNING] All lines rejected in SiteV2_17.txt
# [WARNING] All lines rejected in SiteV2_18.txt
# [WARNING] All lines rejected in SiteV2_19.txt
# [WARNING] All lines rejected in SiteV2_2.txt
# [WARNING] All lines rejected in SiteV2_20.txt
# [WARNING] All lines rejected in SiteV2_21.txt
# [WARNING] All lines rejected in SiteV2_22.txt
# [WARNING] All lines rejected in SiteV2_23.txt
# [WARNING] All lines rejected in SiteV2_24.txt
# [WARNING] All lines rejected in SiteV2_26.txt
# [WARNING] All lines rejected in SiteV2_27.txt
# [WARNING] All lines rejected in SiteV2_3.txt
# [WARNING] All lines rejected in SiteV2_35.txt
# [WARNING] All lines rejected in SiteV2_36.txt
# [WARNING] All lines rejected in SiteV2_39.txt
# [WARNING] All lines rejected in SiteV2_4.txt
# [WARNING] All lines rejected in SiteV2_42.txt
# [WARNING] All lines rejected in SiteV2_43.txt
# [WARNING] All lines rejected in SiteV2_44.txt
# [WARNING] All lines rejected in SiteV2_45.txt
# [WARNING] All lines rejected in SiteV2_46.txt
# [WARNING] All lines rejected in SiteV2_47.txt
# [WARNING] All lines rejected in SiteV2_48.txt
# [WARNING] All lines rejected in SiteV2_5.txt
# [WARNING] All lines rejected in SiteV2_50.txt
# [WARNING] All lines rejected in SiteV2_51.txt
# [WARNING] All lines rejected in SiteV2_52.txt
# [WARNING] All lines rejected in SiteV2_53.txt
# [WARNING] All lines rejected in SiteV2_54.txt
# [WARNING] All lines rejected in SiteV2_55.txt
# [WARNING] All lines rejected in SiteV2_56.txt
# [WARNING] All lines rejected in SiteV2_57.txt
# [WARNING] All lines rejected in SiteV2_58.txt
# [WARNING] All lines rejected in SiteV2_59.txt
# [WARNING] All lines rejected in SiteV2_6.txt
# [WARNING] All lines rejected in SiteV2_60.txt
# [WARNING] All lines rejected in SiteV2_61.txt
# [WARNING] All lines rejected in SiteV2_62.txt
# [WARNING] All lines rejected in SiteV2_63.txt
# [WARNING] All lines rejected in SiteV2_64.txt
# [WARNING] All lines rejected in SiteV2_65.txt
# [WARNING] All lines rejected in SiteV2_67.txt
# [WARNING] All lines rejected in SiteV2_68.txt
# [WARNING] All lines rejected in SiteV2_7.txt
# [WARNING] All lines rejected in SiteV2_8.txt
# [WARNING] All lines rejected in SiteV2_9.txt
#
# DONE! All CSVs saved inside /cleancsvs/
