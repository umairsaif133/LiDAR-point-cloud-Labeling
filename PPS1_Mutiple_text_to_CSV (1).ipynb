# %%
import pandas as pd, glob, re, os

# --- Path containing your .txt files ---
folder_path = r"C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1"

# --- Create output folder ---
output_folder = os.path.join(folder_path, "Potholes_clean_csvs")
os.makedirs(output_folder, exist_ok=True)

# --- Get list of all .txt files ---
txt_files = glob.glob(os.path.join(folder_path, "*.txt"))
print(f"Found {len(txt_files)} .txt files in {folder_path}")

for txt_file in txt_files:
    try:
        # --- Read file ---
        df = pd.read_csv(txt_file, skiprows=1, sep=',', engine='python')
        df = df[["Name", "X", "Y", "Z"]]

        # --- Extract type (P, C, E) and number ---
        def extract_type_and_number(name):
            m = re.search(r'([PCE])(\d+)', name)
            return (m.group(1), int(m.group(2))) if m else (None, -1)
        df[['Type', 'Number']] = df['Name'].apply(lambda x: pd.Series(extract_type_and_number(x)))

        # --- Extract base name (without _S / _F) for proper grouping ---
        df['Base'] = df['Name'].apply(lambda x: re.sub(r'_[SF]$', '', x))

        # --- Define sort keys ---
        df['SF'] = df['Name'].apply(lambda x: 0 if x.endswith('_S') else 1)  # S before F
        order_map = {'P': 1, 'C': 2, 'E': 3}
        df['TypeOrder'] = df['Type'].map(order_map).fillna(99)

        # --- Sort by site type, number, then ensure S comes before F ---
        df = df.sort_values(by=['TypeOrder', 'Number', 'Base', 'SF']).drop(columns=['TypeOrder', 'SF', 'Type', 'Number', 'Base'])

        # --- Define output file path ---
        base_name = os.path.basename(txt_file).replace(".txt", "_clean.csv")
        csv_file = os.path.join(output_folder, base_name)

        # --- Save cleaned CSV ---
        df.to_csv(csv_file, index=False, float_format="%.3f")
        print(f"✅ Saved cleaned CSV → {csv_file}")

    except Exception as e:
        print(f"❌ Error processing {txt_file}: {e}")

print(f"\n🎯 All cleaned CSVs saved in: {output_folder}")
# Out:
# Found 15 .txt files in C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_0_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_1_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_10_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_11_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_12_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_13_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_14_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_2_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_3_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_4_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_5_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_6_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_7_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_8_P_1_S_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs\Site1_9_clean.csv
#
# 🎯 All cleaned CSVs saved in: C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\Potholes_clean_csvs

# %%
import pandas as pd, glob, re, os

# --- Path containing your .txt files ---
folder_path = r"C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1"  # change as needed

# --- Create output folder inside the same directory ---
output_folder = os.path.join(folder_path, "clean_csvs")
os.makedirs(output_folder, exist_ok=True)

# --- Get list of all .txt files ---
txt_files = glob.glob(os.path.join(folder_path, "*.txt"))
print(f"Found {len(txt_files)} .txt files in {folder_path}")

for txt_file in txt_files:
    try:
        # --- Read file ---
        df = pd.read_csv(txt_file, skiprows=1, sep=',', engine='python')
        df = df[["Name", "X", "Y", "Z"]]

        # --- Extract type (P, C, E) and number ---
        def extract_type_and_number(name):
            m = re.search(r'([PCE])_(\d+)', str(name))
            return (m.group(1), int(m.group(2))) if m else (None, -1)

        df[['Type', 'Number']] = df['Name'].apply(lambda x: pd.Series(extract_type_and_number(x)))

        # --- Identify S/F flag ---
        def sf_flag(name):
            if '_S' in name:
                return 0  # S first
            elif '_F' in name:
                return 1  # F second
            else:
                return 2  # others (if any)
        df['SF'] = df['Name'].apply(sf_flag)

        # --- Create a "Base" key to ensure S and F stay together ---
        # Example: Site1_0_P1_S → Site1_0_P1
        df['Base'] = df['Name'].apply(lambda x: re.sub(r'(_[SF])$', '', str(x)))

        # --- Define type ordering ---
        order_map = {'P': 1, 'C': 2, 'E': 3}
        df['TypeOrder'] = df['Type'].map(order_map).fillna(99)

        # --- Sort so that:
        #     1. Type: P → C → E
        #     2. Number ascending
        #     3. Within each pair, S before F
        df = df.sort_values(by=['TypeOrder', 'Number', 'Base', 'SF']).drop(columns=['TypeOrder', 'SF', 'Type', 'Number', 'Base'])

        # --- Define output file path inside new folder ---
        base_name = os.path.basename(txt_file).replace(".txt", "_clean.csv")
        csv_file = os.path.join(output_folder, base_name)

        # --- Save cleaned CSV ---
        df.to_csv(csv_file, index=False, float_format="%.3f")
        print(f"✅ Saved cleaned CSV → {csv_file}")

    except Exception as e:
        print(f"❌ Error processing {txt_file}: {e}")

print(f"\n🎯 All cleaned CSVs saved in: {output_folder}")
# Out:
# Found 15 .txt files in C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_0_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_1_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_10_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_11_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_12_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_13_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_14_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_2_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_3_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_4_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_5_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_6_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_7_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_8_P_1_S_clean.csv
# ✅ Saved cleaned CSV → C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs\Site1_9_clean.csv
#
# 🎯 All cleaned CSVs saved in: C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/site1\clean_csvs

# %%
import os
import pandas as pd
import re

# -------------------------------------
# Utility: normalize the first token
# -------------------------------------
def normalize_code(code):
    """
    Takes first token: 'Site8_0_Fl_S_4'
    Applies corrections and returns dict fields.
    """
    code = code.strip()

    # Force normalized Fl form
    code = re.sub(r'(Flushed|FLUSHED|flushed|FL|fl)', 'Fl', code)

    parts = re.split(r'[_-]', code)

    # Expected formats like:
    # Site8, 0, Fl, S, 4
    # Site8, 0, P, F, 2
    # SiteV2, 58, C, S, 11
    # etc.

    if len(parts) < 4:
        return None

    # Identify site
    site = parts[0]
    sub = parts[1]

    # Identify labels
    # type = P, C, E, Fl
    # sf (START/FINISH) = S or F
    # num = integer
    types = ["P", "C", "E", "Fl"]

    type_token = None
    sf_token = None
    num_token = None

    for p in parts[2:]:
        if p in types:
            type_token = p
        elif p in ["S", "F"]:
            sf_token = p
        elif p.isdigit():
            num_token = int(p)

    # Require S/F
    if sf_token is None:
        return None

    if type_token is None or num_token is None:
        return None

    return {
        "site": site,
        "sub": sub,
        "type": type_token,
        "num": num_token,
        "SF": sf_token,
        "raw": code
    }


# -------------------------------------------------------
# Build final unified string as per your naming standard
# -------------------------------------------------------
def build_name(row):
    # Example: Site8_0_Fl4_S
    return f"{row['site']}_{row['sub']}_{row['type']}{row['num']}_{row['SF']}"


# -------------------------------------------------------
# PROCESS ONE TXT → one CSV with SAME NAME
# -------------------------------------------------------
def process_txt_file(txt_path, out_dir):
    filename = os.path.basename(txt_path)

    cleaned_rows = []

    with open(txt_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            # Split CSV-like row
            first_token = line.split(",")[0]

            parsed = normalize_code(first_token)
            if parsed is not None:
                cleaned_rows.append(parsed)

    if not cleaned_rows:
        print(f"[WARNING] All lines rejected in {filename}")
        return

    df = pd.DataFrame(cleaned_rows)

    # Sorting rule: P < C < E < Fl
    sort_order = {"P": 1, "C": 2, "E": 3, "Fl": 4}

    df["type_order"] = df["type"].map(sort_order)

    df = df.sort_values(by=["site", "sub", "type_order", "num", "SF"])

    # Build final name
    df["final_name"] = df.apply(build_name, axis=1)

    # Save with SAME filename but CSV extension
    out_csv = os.path.join(out_dir, filename.replace(".txt", ".csv"))
    df.to_csv(out_csv, index=False)

    print(f"[OK] Saved {out_csv}, rows={len(df)}")


# ------------------------------
# MAIN EXECUTION
# ------------------------------
input_folder = "C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables"
output_folder = "C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs"
os.makedirs(output_folder, exist_ok=True)

for file in os.listdir(input_folder):
    if file.lower().endswith(".txt"):
        process_txt_file(os.path.join(input_folder, file), output_folder)

print("\nDONE — All CSVs saved in cleancsvs/")
# Out:
# [WARNING] All lines rejected in Site1_0.txt
# [WARNING] All lines rejected in Site1_1.txt
# [WARNING] All lines rejected in Site1_10.txt
# [WARNING] All lines rejected in Site1_11.txt
# [WARNING] All lines rejected in Site1_12.txt
# [WARNING] All lines rejected in Site1_13.txt
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_14.csv, rows=30
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_2.csv, rows=22
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_3.csv, rows=36
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_4.csv, rows=24
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_5.csv, rows=20
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_6.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_7.csv, rows=36
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_8.csv, rows=18
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site1_9.csv, rows=48
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_0.csv, rows=97
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_1.csv, rows=226
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_10.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_11.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_2.csv, rows=86
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_3.csv, rows=32
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_4.csv, rows=18
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_5.csv, rows=44
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_7.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site2_9.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site3_0.csv, rows=82
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site3_1.csv, rows=146
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site3_2.csv, rows=168
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site3_3.csv, rows=248
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site3_4.csv, rows=44
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_0.csv, rows=114
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_1.csv, rows=92
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_10.csv, rows=10
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_11.csv, rows=44
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_2.csv, rows=86
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_3.csv, rows=112
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_4.csv, rows=120
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_5.csv, rows=114
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_6.csv, rows=34
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_7.csv, rows=42
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site4_8.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_0.csv, rows=14
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_1.csv, rows=40
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_10.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_11.csv, rows=34
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_12.csv, rows=28
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_13.csv, rows=92
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_14.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_16.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_17.csv, rows=24
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_18.csv, rows=122
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_19.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_2.csv, rows=10
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_3.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_4.csv, rows=12
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_5.csv, rows=14
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_6.csv, rows=14
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_7.csv, rows=30
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site5_8.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site6_0.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site6_1.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site6_11.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site6_3.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site6_5.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site6_7.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site7_0.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site7_1.csv, rows=18
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site7_2.csv, rows=10
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_0.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_1.csv, rows=20
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_10.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_11.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8p2_2.csv, rows=23
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_3.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_4.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_5.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_6.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_7.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_8.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8P2_9.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_0.csv, rows=20
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_1.csv, rows=16
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_2.csv, rows=10
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_4.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_5.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_6.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\Site8_7.csv, rows=18
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV1_1.csv, rows=12
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV1_2.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV1_3.csv, rows=10
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV1_4.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV1_5.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV1_6.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_0.csv, rows=26
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_1.csv, rows=64
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_11.csv, rows=8
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_12.csv, rows=2
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_14.csv, rows=32
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_15.csv, rows=7
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_16.csv, rows=12
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_17.csv, rows=36
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_18.csv, rows=48
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_19.csv, rows=16
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_2.csv, rows=74
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_20.csv, rows=26
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_21.csv, rows=46
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_22.csv, rows=14
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_23.csv, rows=4
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_24.csv, rows=18
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_26.csv, rows=16
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_27.csv, rows=20
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_3.csv, rows=80
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_35.csv, rows=26
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_36.csv, rows=28
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_39.csv, rows=10
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_4.csv, rows=94
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_42.csv, rows=12
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_43.csv, rows=102
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_44.csv, rows=64
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_45.csv, rows=420
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_46.csv, rows=100
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_47.csv, rows=16
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_48.csv, rows=38
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_5.csv, rows=130
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_50.csv, rows=128
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_51.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_52.csv, rows=52
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_53.csv, rows=62
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_54.csv, rows=210
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_55.csv, rows=62
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_56.csv, rows=14
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_57.csv, rows=24
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_58.csv, rows=78
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_59.csv, rows=120
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_6.csv, rows=76
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_60.csv, rows=48
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_61.csv, rows=6
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_62.csv, rows=134
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_63.csv, rows=392
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_64.csv, rows=302
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_65.csv, rows=408
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_67.csv, rows=140
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_68.csv, rows=130
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_7.csv, rows=46
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_8.csv, rows=30
# [OK] Saved C:/Users/umair.muhammad/Documents/PhD/Research Work/FedLearn/training/All_Nome/txt_lables/cleancsvs\SiteV2_9.csv, rows=34
#
# DONE — All CSVs saved in cleancsvs/

# %%
import os
import csv
import re

input_folder = r"C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables"
output_folder = os.path.join(input_folder, "cleancsvs")

os.makedirs(output_folder, exist_ok=True)

LABELS = ["P", "C", "E", "FL"]


def find_label(name):
    """Find P, C, E, Fl ANYWHERE in the name."""
    n = name.upper()

    # Priority: Fl first (two letters)
    if "FL" in n:
        return "Fl"

    # Single-letter labels
    for L in ["P", "C", "E"]:
        if L in n:
            return L

    return None


def has_final_SF(name):
    """
    Check if the name ends with S or F ANYWHERE before numbers.
    We look for last alphabetic character.
    """
    letters = re.findall("[A-Za-z]", name)
    if not letters:
        return False

    last = letters[-1].upper()
    return last in ["S", "F"]


def clean_name(name):
    """Normalize double underscores etc."""
    name = name.replace("__", "_")
    name = re.sub(r"_+", "_", name)
    return name.strip()


for filename in os.listdir(input_folder):
    if not filename.lower().endswith(".txt"):
        continue

    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename.replace(".txt", ".csv"))

    saved = 0
    rejected = 0
    rows = []

    with open(input_path, "r", errors="ignore") as f:
        for line in f:
            parts = [p.strip() for p in line.split(",")]

            if len(parts) < 4:
                rejected += 1
                continue

            name = clean_name(parts[0])

            # Extract coordinates
            try:
                X = float(parts[1])
                Y = float(parts[2])
                Z = float(parts[3])
            except:
                rejected += 1
                continue

            # Find label anywhere in name
            label = find_label(name)
            if label is None:
                rejected += 1
                continue

            # Check F / S anywhere at end
            if not has_final_SF(name):
                rejected += 1
                continue

            rows.append([name, X, Y, Z, label])
            saved += 1

    if rows:
        with open(output_path, "w", newline="") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(["Damage_ID", "X", "Y", "Z", "Label"])
            writer.writerows(rows)
        print(f"[OK] {filename} -> {output_path}  (total={saved+rejected}, saved={saved}, rejected={rejected})")
    else:
        print(f"[WARNING] All lines rejected in {filename} (total={saved+rejected})")
# Out:
# [OK] Site1_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_0.csv  (total=4, saved=2, rejected=2)
# [OK] Site1_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_1.csv  (total=42, saved=40, rejected=2)
# [OK] Site1_10.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_10.csv  (total=88, saved=76, rejected=12)
# [OK] Site1_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_11.csv  (total=64, saved=62, rejected=2)
# [OK] Site1_12.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_12.csv  (total=72, saved=70, rejected=2)
# [OK] Site1_13.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_13.csv  (total=20, saved=18, rejected=2)
# [OK] Site1_14.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_14.csv  (total=32, saved=30, rejected=2)
# [OK] Site1_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_2.csv  (total=24, saved=22, rejected=2)
# [OK] Site1_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_3.csv  (total=38, saved=36, rejected=2)
# [OK] Site1_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_4.csv  (total=26, saved=24, rejected=2)
# [OK] Site1_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_5.csv  (total=22, saved=20, rejected=2)
# [OK] Site1_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_6.csv  (total=8, saved=6, rejected=2)
# [OK] Site1_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_7.csv  (total=38, saved=36, rejected=2)
# [OK] Site1_8.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_8.csv  (total=20, saved=18, rejected=2)
# [OK] Site1_9.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site1_9.csv  (total=50, saved=48, rejected=2)
# [OK] Site2_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_0.csv  (total=100, saved=98, rejected=2)
# [OK] Site2_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_1.csv  (total=228, saved=226, rejected=2)
# [OK] Site2_10.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_10.csv  (total=9, saved=2, rejected=7)
# [OK] Site2_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_11.csv  (total=8, saved=6, rejected=2)
# [OK] Site2_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_2.csv  (total=88, saved=86, rejected=2)
# [OK] Site2_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_3.csv  (total=34, saved=32, rejected=2)
# [OK] Site2_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_4.csv  (total=20, saved=18, rejected=2)
# [OK] Site2_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_5.csv  (total=46, saved=44, rejected=2)
# [OK] Site2_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_7.csv  (total=8, saved=6, rejected=2)
# [OK] Site2_9.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site2_9.csv  (total=8, saved=6, rejected=2)
# [OK] Site3_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site3_0.csv  (total=84, saved=82, rejected=2)
# [OK] Site3_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site3_1.csv  (total=148, saved=146, rejected=2)
# [OK] Site3_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site3_2.csv  (total=170, saved=168, rejected=2)
# [OK] Site3_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site3_3.csv  (total=250, saved=248, rejected=2)
# [OK] Site3_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site3_4.csv  (total=46, saved=44, rejected=2)
# [OK] Site4_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_0.csv  (total=117, saved=114, rejected=3)
# [OK] Site4_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_1.csv  (total=94, saved=92, rejected=2)
# [OK] Site4_10.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_10.csv  (total=12, saved=10, rejected=2)
# [OK] Site4_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_11.csv  (total=46, saved=44, rejected=2)
# [OK] Site4_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_2.csv  (total=88, saved=86, rejected=2)
# [OK] Site4_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_3.csv  (total=114, saved=112, rejected=2)
# [OK] Site4_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_4.csv  (total=122, saved=120, rejected=2)
# [OK] Site4_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_5.csv  (total=116, saved=114, rejected=2)
# [OK] Site4_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_6.csv  (total=36, saved=34, rejected=2)
# [OK] Site4_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_7.csv  (total=44, saved=42, rejected=2)
# [OK] Site4_8.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site4_8.csv  (total=10, saved=8, rejected=2)
# [OK] Site5_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_0.csv  (total=16, saved=14, rejected=2)
# [OK] Site5_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_1.csv  (total=42, saved=40, rejected=2)
# [OK] Site5_10.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_10.csv  (total=4, saved=2, rejected=2)
# [OK] Site5_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_11.csv  (total=36, saved=34, rejected=2)
# [OK] Site5_12.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_12.csv  (total=30, saved=28, rejected=2)
# [OK] Site5_13.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_13.csv  (total=94, saved=92, rejected=2)
# [OK] Site5_14.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_14.csv  (total=8, saved=6, rejected=2)
# [OK] Site5_16.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_16.csv  (total=4, saved=2, rejected=2)
# [OK] Site5_17.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_17.csv  (total=26, saved=24, rejected=2)
# [OK] Site5_18.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_18.csv  (total=124, saved=122, rejected=2)
# [OK] Site5_19.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_19.csv  (total=6, saved=4, rejected=2)
# [OK] Site5_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_2.csv  (total=12, saved=10, rejected=2)
# [OK] Site5_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_3.csv  (total=10, saved=8, rejected=2)
# [OK] Site5_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_4.csv  (total=14, saved=12, rejected=2)
# [OK] Site5_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_5.csv  (total=16, saved=14, rejected=2)
# [OK] Site5_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_6.csv  (total=16, saved=14, rejected=2)
# [OK] Site5_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_7.csv  (total=32, saved=30, rejected=2)
# [OK] Site5_8.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site5_8.csv  (total=4, saved=2, rejected=2)
# [OK] Site6_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site6_0.csv  (total=4, saved=2, rejected=2)
# [OK] Site6_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site6_1.csv  (total=4, saved=2, rejected=2)
# [OK] Site6_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site6_11.csv  (total=4, saved=2, rejected=2)
# [OK] Site6_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site6_3.csv  (total=4, saved=2, rejected=2)
# [OK] Site6_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site6_5.csv  (total=6, saved=4, rejected=2)
# [OK] Site6_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site6_7.csv  (total=4, saved=2, rejected=2)
# [OK] Site7_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site7_0.csv  (total=4, saved=2, rejected=2)
# [OK] Site7_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site7_1.csv  (total=20, saved=18, rejected=2)
# [OK] Site7_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site7_2.csv  (total=12, saved=10, rejected=2)
# [OK] Site8P2_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_0.csv  (total=8, saved=6, rejected=2)
# [OK] Site8P2_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_1.csv  (total=22, saved=20, rejected=2)
# [OK] Site8P2_10.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_10.csv  (total=8, saved=6, rejected=2)
# [OK] Site8P2_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_11.csv  (total=6, saved=4, rejected=2)
# [OK] Site8p2_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8p2_2.csv  (total=25, saved=23, rejected=2)
# [OK] Site8P2_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_3.csv  (total=6, saved=4, rejected=2)
# [OK] Site8P2_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_4.csv  (total=4, saved=2, rejected=2)
# [OK] Site8P2_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_5.csv  (total=10, saved=8, rejected=2)
# [OK] Site8P2_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_6.csv  (total=8, saved=6, rejected=2)
# [OK] Site8P2_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_7.csv  (total=8, saved=6, rejected=2)
# [OK] Site8P2_8.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_8.csv  (total=8, saved=6, rejected=2)
# [OK] Site8P2_9.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8P2_9.csv  (total=10, saved=8, rejected=2)
# [OK] Site8_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_0.csv  (total=22, saved=20, rejected=2)
# [OK] Site8_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_1.csv  (total=18, saved=16, rejected=2)
# [OK] Site8_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_2.csv  (total=12, saved=10, rejected=2)
# [OK] Site8_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_4.csv  (total=6, saved=4, rejected=2)
# [OK] Site8_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_5.csv  (total=6, saved=4, rejected=2)
# [OK] Site8_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_6.csv  (total=8, saved=6, rejected=2)
# [OK] Site8_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\Site8_7.csv  (total=20, saved=18, rejected=2)
# [OK] SiteV1_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV1_1.csv  (total=14, saved=12, rejected=2)
# [OK] SiteV1_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV1_2.csv  (total=8, saved=6, rejected=2)
# [OK] SiteV1_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV1_3.csv  (total=12, saved=10, rejected=2)
# [OK] SiteV1_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV1_4.csv  (total=6, saved=4, rejected=2)
# [OK] SiteV1_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV1_5.csv  (total=10, saved=8, rejected=2)
# [OK] SiteV1_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV1_6.csv  (total=10, saved=8, rejected=2)
# [OK] SiteV2_0.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_0.csv  (total=28, saved=26, rejected=2)
# [OK] SiteV2_1.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_1.csv  (total=66, saved=64, rejected=2)
# [OK] SiteV2_11.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_11.csv  (total=10, saved=8, rejected=2)
# [OK] SiteV2_12.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_12.csv  (total=4, saved=2, rejected=2)
# [OK] SiteV2_14.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_14.csv  (total=34, saved=32, rejected=2)
# [OK] SiteV2_15.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_15.csv  (total=16, saved=7, rejected=9)
# [OK] SiteV2_16.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_16.csv  (total=14, saved=12, rejected=2)
# [OK] SiteV2_17.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_17.csv  (total=38, saved=36, rejected=2)
# [OK] SiteV2_18.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_18.csv  (total=50, saved=48, rejected=2)
# [OK] SiteV2_19.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_19.csv  (total=18, saved=16, rejected=2)
# [OK] SiteV2_2.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_2.csv  (total=76, saved=74, rejected=2)
# [OK] SiteV2_20.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_20.csv  (total=28, saved=26, rejected=2)
# [OK] SiteV2_21.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_21.csv  (total=48, saved=46, rejected=2)
# [OK] SiteV2_22.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_22.csv  (total=16, saved=14, rejected=2)
# [OK] SiteV2_23.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_23.csv  (total=6, saved=4, rejected=2)
# [OK] SiteV2_24.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_24.csv  (total=20, saved=18, rejected=2)
# [OK] SiteV2_26.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_26.csv  (total=18, saved=16, rejected=2)
# [OK] SiteV2_27.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_27.csv  (total=22, saved=20, rejected=2)
# [OK] SiteV2_3.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_3.csv  (total=82, saved=80, rejected=2)
# [OK] SiteV2_35.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_35.csv  (total=28, saved=26, rejected=2)
# [OK] SiteV2_36.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_36.csv  (total=30, saved=28, rejected=2)
# [OK] SiteV2_39.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_39.csv  (total=12, saved=10, rejected=2)
# [OK] SiteV2_4.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_4.csv  (total=96, saved=94, rejected=2)
# [OK] SiteV2_42.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_42.csv  (total=14, saved=12, rejected=2)
# [OK] SiteV2_43.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_43.csv  (total=104, saved=102, rejected=2)
# [OK] SiteV2_44.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_44.csv  (total=66, saved=64, rejected=2)
# [OK] SiteV2_45.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_45.csv  (total=422, saved=420, rejected=2)
# [OK] SiteV2_46.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_46.csv  (total=102, saved=100, rejected=2)
# [OK] SiteV2_47.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_47.csv  (total=18, saved=16, rejected=2)
# [OK] SiteV2_48.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_48.csv  (total=40, saved=38, rejected=2)
# [OK] SiteV2_5.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_5.csv  (total=132, saved=130, rejected=2)
# [OK] SiteV2_50.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_50.csv  (total=130, saved=128, rejected=2)
# [OK] SiteV2_51.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_51.csv  (total=8, saved=6, rejected=2)
# [OK] SiteV2_52.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_52.csv  (total=54, saved=52, rejected=2)
# [OK] SiteV2_53.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_53.csv  (total=64, saved=62, rejected=2)
# [OK] SiteV2_54.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_54.csv  (total=212, saved=210, rejected=2)
# [OK] SiteV2_55.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_55.csv  (total=64, saved=62, rejected=2)
# [OK] SiteV2_56.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_56.csv  (total=16, saved=14, rejected=2)
# [OK] SiteV2_57.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_57.csv  (total=26, saved=24, rejected=2)
# [OK] SiteV2_58.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_58.csv  (total=80, saved=78, rejected=2)
# [OK] SiteV2_59.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_59.csv  (total=122, saved=120, rejected=2)
# [OK] SiteV2_6.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_6.csv  (total=78, saved=76, rejected=2)
# [OK] SiteV2_60.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_60.csv  (total=50, saved=48, rejected=2)
# [OK] SiteV2_61.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_61.csv  (total=8, saved=6, rejected=2)
# [OK] SiteV2_62.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_62.csv  (total=136, saved=134, rejected=2)
# [OK] SiteV2_63.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_63.csv  (total=394, saved=392, rejected=2)
# [OK] SiteV2_64.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_64.csv  (total=304, saved=302, rejected=2)
# [OK] SiteV2_65.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_65.csv  (total=410, saved=408, rejected=2)
# [OK] SiteV2_67.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_67.csv  (total=142, saved=140, rejected=2)
# [OK] SiteV2_68.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_68.csv  (total=132, saved=130, rejected=2)
# [OK] SiteV2_7.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_7.csv  (total=48, saved=46, rejected=2)
# [OK] SiteV2_8.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_8.csv  (total=32, saved=30, rejected=2)
# [OK] SiteV2_9.txt -> C:\Users\umair.muhammad\Documents\PhD\Research Work\FedLearn\training\All_Nome\txt_lables\cleancsvs\SiteV2_9.csv  (total=36, saved=34, rejected=2)
